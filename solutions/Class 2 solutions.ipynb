# %% [markdown]
# ## Module 2 Class activities
# This notebook is a starting point for the exercises and activities that we'll do in class.
#
# Before you attempt any of these activities, make sure to watch the video lectures for this module.

# %% [markdown]
# ### Scraping permit data
# Here's the code that we saw in the video lecture that queries the City of Seattle permit website, gets a dataframe of permits (including the URL), and then digs down further into that permit-specific URL.

# %%
# get the permit data from the API
import json
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

url = 'https://data.seattle.gov/resource/ht3q-kdvx.json' # copied and pasted from the webpage
r = requests.get(url)
df = pd.DataFrame(json.loads(r.text))

df = df.head(20) # get the first 5 rows, so we don't overload the city's website.

# get an example link
permiturl = df.loc[8,'link']['url']
print(permiturl)

# request that page and get the soup object
r = requests.get(permiturl)
soup = BeautifulSoup(r.text)
#print(soup.prettify())

# %%
# then we wrote this code to extract the project description 
links = soup.find_all('td')
for link in links:
    if 'Project Description' in link.text: 
        sublinks = link.find_all('td')
        description = sublinks[1].text
        # once we find a description, we exit
        break
    
print(description)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> If you look at the example, there may be a section giving information on the number of curb cuts. Extract that to a variable and print it.
# </div>

# %%
# Hints
# Not all of the records have the curb cut field. You can see an example here:
# https://services.seattle.gov/portal/customize/LinkToRecord.aspx?altId=3001776-LU

    # If you look at that webpage, you'll see that the text "Number of Curb Cuts for This Permit: "
# is within "span" tags
curbcuttext = soup.find("span", string="Number of Curb Cuts for This Permit: ")

# So to get the number of curb cuts (which is the next piece of text), 
# you can ask for the NEXT tag using find_next()
#n_curbcuts = curbcuttext.find_next()

# you'll need to add an if statement to deal with the case when this text does not exist
    
# your code here
# all I did was extract the text, and add the if statement
if curbcuttext is None:
    n_curbcuts = np.nan
else:
    n_curbcuts = int(curbcuttext.find_next().text)
print(n_curbcuts)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> Now turn that into a function that you can apply to each row of your dataframe. Add a new column, <strong>n_curbcuts</strong>, to your dataframe.
# </div>

# %%
# your code here

# I just copied and pasted the code above
# and indented it into a function
def get_curbcuts(urldict):
    permiturl = urldict['url']
    
    r = requests.get(permiturl)
    soup = BeautifulSoup(r.text)
    
    curbcuttext = soup.find("span", string="Number of Curb Cuts for This Permit: ")
    
    if curbcuttext is None:
        n_curbcuts = np.nan
    else:
        n_curbcuts = int(curbcuttext.find_next().text)

    print(n_curbcuts)
    return(n_curbcuts)
    

get_curbcuts(df.loc[8,'link'])

# %% [markdown]
# ### Fixing errors
# We'll do more scraping in just a moment. But first, let's do some examples of how to interpret an error message, and fix it.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> Each of the cells below will generate an error. Look at the error message and see if you can figure out how to fix it. (Don't Google it until you try to figure it out based on the error message.)
# </div>

# %%
# the housingunitsremoved and housingunitsadded give useful information
# let's create a new column with netunits
df['netunits'] = df.housingunitsadded - df.housingunitsremoved

# %%
# SOLUTION: we need to convert them to a float first
df['netunits'] = df.housingunitsadded.astype(float) - df.housingunitsremoved.astype(float)
df['netunits']

# %%
# print the address of the first row
print('Address of first row is {}. Permit type is {}'.format(df.iloc[0].originaladdress1))

# %%
# SOLUTION: We had two placeholders {} but only one variable to insert into them
# We could delete one of the {} or add a second argument to the format()
print('Address of first row is {}. Permit type is'.format(df.iloc[0].originaladdress1))
print('Address of first row is {}. Permit type is {}'.format(df.iloc[0].originaladdress1, df.iloc[0].permitclass))

# %%
# Convert the number of housing units to integers
# and then summarize

df['unitsadded_numeric'] = df.housingunitsadded.astype(int)
df.unitsadded_numeric.describe(

# %%
# SOLUTION: the first problem was our missing parenthesis

df['unitsadded_numeric'] = df.housingunitsadded.astype(int)
df.unitsadded_numeric.describe()

# %%
# our second problem was the data type. An integer type cannot hold NaN
# so we do float
df['unitsadded_numeric'] = df.housingunitsadded.astype(float)
df.unitsadded_numeric.describe()

# %% [markdown]
# ### Scraping craigslist
#
# In the lecture, we saw how to scrape the main page (the list of posts).
#
# What if you want to get more information about (say) a particular apartment?
#
# Go to the [craigslist housing page](https://losangeles.craigslist.org/search/apa#search=1~gallery~0~0) and copy the link for one of the listings. It should look something like this:
# https://losangeles.craigslist.org/lgb/apa/d/long-beach-home-for-rent/7597309102.html
#
# (It's fine to copy and paste the URL for now. A second step would be to loop over the URLs from the dataframe of postings that we created in the video lecture, but in class, we'll just focus on one example.)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <strong>Exercise:</strong> For this URL, use requests to get the content of the post. (No need to create a soup object yet.)
# </div>

# %%
import json
import requests
import pandas as pd
from bs4 import BeautifulSoup

# your code here
# put the output of the request in a variable called r
# so you can access the content like this
url = 'https://losangeles.craigslist.org/ant/apa/d/valencia-charming-br-ba-with-1000-off/7838334390.html'
r = requests.get(url)
print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n    \n\t<meta charset="UTF-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge">\n\t<meta name="viewport" content="width=device-width,initial-scale=1">\n\t<meta property="og:site_name" content="craigslist">\n\t<meta name="twitter:card" content="preview">\n\t<meta property="og:title" content="Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! - apts/housing for rent - apartment rent - craigslist">\n\t<meta name="description" content="22640 Garzota Dr, Santa Clarita, CA 91350 Welcome to Arrive Santa Clarita, a captivating community offering luxurious one- and two-bedroom apartment homes. Relish the serenity of the nearby...">\n\t<meta property="og:description" content="22640 Garzota Dr, Santa Clarita, CA 91350 Welcome to Arrive Santa Clarita, a captivating community offering luxurious one- and two-bedroom apartment homes. Relish the serenity of the nearby...">\n\t<meta property="og:image" content="https://images.craigslist.org/00d0d_hp0VIOcQjyz_0pO0hd_600x450.jpg">\n\t<meta property="og:url" content="https://losangeles.craigslist.org/ant/apa/d/valencia-charming-br-ba-with-1000-off/7838334390.html">\n\t<meta property="og:type" content="article">\n\t<meta name="robots" content="unavailable_after: 2025-05-15T23:28:32Z">\n\t<meta name="geo.position" content="34.437459;-118.531770">\n\t<meta name="ICBM" content="34.437459, -118.531770">\n\t<meta name="geo.placename" content="Santa Clarita">\n\t<meta name="geo.region" content="US-CA">\n\t<title>Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! - apts/housing for rent - apartment rent - craigslist</title>\n\t<link rel="canonical" href="https://losangeles.craigslist.org/ant/apa/d/valencia-charming-br-ba-with-1000-off/7838334390.html">\n\t<link rel="alternate" href="https://losangeles.craigslist.org/ant/apa/d/valencia-charming-br-ba-with-1000-off/7838334390.html" hreflang="x-default">\n\n\n\n    <link rel="icon" href="/favicon.ico" id="favicon" />\n\n<script type="application/ld+json" id="ld_breadcrumb_data" >\n    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"item":"https://losangeles.craigslist.org","name":"losangeles.craigslist.org","position":1,"@type":"ListItem"},{"name":"antelope valley","position":2,"item":"https://losangeles.craigslist.org/ant/","@type":"ListItem"},{"@type":"ListItem","name":"housing","position":3,"item":"https://losangeles.craigslist.org/search/ant/hhh"},{"name":"apartments / housing for rent","position":4,"item":"https://losangeles.craigslist.org/search/ant/apa","@type":"ListItem"},{"item":"https://losangeles.craigslist.org/ant/apa/d/valencia-charming-br-ba-with-1000-off/7838334390.html","name":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!","position":5,"@type":"ListItem"}]}\n</script>\n\n<script type="application/ld+json" id="ld_posting_data" >\n    {"@context":"http://schema.org","numberOfBathroomsTotal":1,"numberOfBedrooms":"2","address":{"postalCode":"91354","addressCountry":"US","addressRegion":"CA","addressLocality":"Valencia","streetAddress":"22640 Garzota Dr","@type":"PostalAddress"},"name":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!","smokingAllowed":false,"latitude":"34.437459","@type":"Apartment","longitude":"-118.531770","petsAllowed":true}\n</script>\n\n\n    <style>\n        body {\n            font-family: sans-serif;\n        }\n\n        #no-js {\n            position: fixed;\n            z-index: 100000;\n            top: 0;\n            bottom: 0;\n            left: 0;\n            right: 0;\n            overflow:auto;\n            margin: 0;\n            background: transparent;\n        }\n\n        #no-js h1 {\n            margin: 0;\n            padding: .5em;\n            color: #00E;\n            background-color: #cccccc;\n        }\n\n        #no-js  p {\n            margin: 1em;\n        }\n\n        .no-js header,\n        .no-js form,\n        .no-js .tsb,\n        .unsupported-browser header,\n  ...

# %% [markdown]
# Now let's extract more information from the page. We have a couple of strategies here. First, we could skip trying to parse the page with `BeautifulSoup`, and just see if particular bits of text are present.
#
# For example, what transportation modes does the post emphasize? Do they mention Section 8 vouchers? Some of this might be exploratory—we can see what type of language is included, and then parse in a more structured way (e.g. distinguishing between "No Section 8" and "Section 8 welcome").

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Exercise:</strong> Write a function that will return True if Section 8 is mentioned, otherwise False.

# %% [markdown]
# *Hint*: the `in` operator is a simple way to do this. For example:

# %%
'plan' in 'urban planning'
# Out:
# True

# %%
'plan' in 'Urban Planning'
# Out:
# False

# %%
# your code here to return Section 8 information

# we can use the same approach to see 
# if a string is in the text that we retrieved via requests
# note the use of lower() to avoid case sensitivity
'section 8' in r.text.lower()
# Out:
# False

# %%
# but this will return True if the text is in the string
'los angeles' in r.text.lower()
# Out:
# True

# %%
# so let's put this in a function
#r.textのように.textを付けると、
#.lower()は、section 8の中の大文字・小文字の違い（Section 8やSECTION 8など）の認識をoffにする、という指示

def sect8(url):
   r = requests.get(url)
   return 'section 8' in r.text.lower()

# test it
sect8(url)
# Out:
# False

# %% [markdown]
# Most of the post is free-form text. So there's not going to be much value added by `BeautifulSoup`.
#
# The exceptions are (i) parking, and (ii) the geographic coordinates.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Exercise:</strong> Write a function that will return True if the apartment has no parking, and also returns the lat/lon of the apartment

# %% [markdown]
# *Hint*: First, create a `soup` object. Then, look and see what tag and class encloses this information. Then, you can experiment with `find` and `find_all` with this tag and class.

# %%
# your code here

# replace with your own url
url = 'https://losangeles.craigslist.org/ant/apa/d/valencia-charming-br-ba-with-1000-off/7838334390.html'

# get a soup object
r = requests.get(url)
soup = BeautifulSoup(r.content)
print(soup.prettify())

#ここれは、r.textではなくr.contentを使っている。基本はr.textでよい。
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="craigslist" property="og:site_name"/>
#   <meta content="preview" name="twitter:card"/>
#   <meta content="Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! - apts/housing for rent - apartment rent - craigslist" property="og:title"/>
#   <meta content="22640 Garzota Dr, Santa Clarita, CA 91350 Welcome to Arrive Santa Clarita, a captivating community offering luxurious one- and two-bedroom apartment homes. Relish the serenity of the nearby..." name="description"/>
#   <meta content="22640 Garzota Dr, Santa Clarita, CA 91350 Welcome to Arrive Santa Clarita, a captivating community offering luxurious one- and two-bedroom apartment homes. Relish the serenity of the nearby..." property="og:description"/>
#   <meta content="https://images.craigslist.org/00d0d_hp0VIOcQjyz_0pO0hd_600x450.jpg" property="og:image"/>
#   <meta content="https://losangeles.craigslist.org/ant/apa/d/valencia-charming-br-ba-with-1000-off/7838334390.html" property="og:url"/>
#   <meta content="article" property="og:type"/>
#   <meta content="unavailable_after: 2025-05-15T23:28:32Z" name="robots"/>
#   <meta content="34.437459;-118.531770" name="geo.position"/>
#   <meta content="34.437459, -118.531770" name="ICBM"/>
#   <meta content="Santa Clarita" name="geo.placename"/>
#   <meta content="US-CA" name="geo.region"/>
#   <title>
#    Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! - apts/housing for rent - apartment rent - craigslist
#   </title>
#   <link href="https://losangeles.craigslist.org/ant/apa/d/valencia-charming-br-ba-with-1000-off/7838334390.html" rel="canonical"/>
#   <link href="https://losangeles.craigslist.org/ant/apa/d/valencia-charming-br-ba-with-1000-off/7838334390.html" hreflang="x-default" rel="alternate"/>
#   <link href="/favicon.ico" id="favicon" rel="icon">
#    <script id="ld_breadcrumb_data" type="application/ld+json">
#     {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"item":"https://losangeles.craigslist.org","name":"losangeles.craigslist.org","position":1,"@type":"ListItem"},{"name":"antelope valley","position":2,"item":"https://losangeles.craigslist.org/ant/","@type":"ListItem"},{"@type":"ListItem","name":"housing","position":3,"item":"https://losangeles.craigslist.org/search/ant/hhh"},{"name":"apartments / housing for rent","position":4,"item":"https://losangeles.craigslist.org/search/ant/apa","@type":"ListItem"},{"item":"https://losangeles.craigslist.org/ant/apa/d/valencia-charming-br-ba-with-1000-off/7838334390.html","name":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!","position":5,"@type":"ListItem"}]}
#    </script>
#    <script id="ld_posting_data" type="application/ld+json">
#     {"@context":"http://schema.org","numberOfBathroomsTotal":1,"numberOfBedrooms":"2","address":{"postalCode":"91354","addressCountry":"US","addressRegion":"CA","addressLocality":"Valencia","streetAddress":"22640 Garzota Dr","@type":"PostalAddress"},"name":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!","smokingAllowed":false,"latitude":"34.437459","@type":"Apartment","longitude":"-118.531770","petsAllowed":true}
#    </script>
#    <style>
#     body {
#             font-family: sans-serif;
#         }
#
#         #no-js {
#             position: fixed;
#             z-index: 100000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             overflow:auto;
#             margin: 0;
#             background: transparent;
#         }
#
#         #no-js h1 {
#             margin: 0;
#             padding: .5em;
#             color: #00E;
#             background-color: #cccccc;
#         }
#
#         #no-js  p {
#             margin: 1em;
#         }
#
#         .no-js header,
#         .no-js form,
#         .no-js .tsb,
#         .unsupported-browser header,
#         .unsupported-browser form,
#         .unsupported-browser .tsb {
#             display: none;
#         }
#
#         #curtain {
#             display: none;
#             position: fixed;
#             z-index: 9000;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#             background: transparent;
#         }
#
#         .show-curtain #curtain {
#             display: block;
#         }
#
#         #curtain .cover,
#         #curtain .content {
#             position: absolute;
#             display: block;
#             top: 0;
#             bottom: 0;
#             left: 0;
#             right: 0;
#             margin: 0;
#             padding: 0;
#             border: 0;
#         }
#
#         #curtain .cover {
#             z-index: 1;
#             background-color: white;
#         }
#
#         .show-curtain #curtain .cover {
#             opacity: 0.7;
#         }
#
#         .show-curtain.clear #curtain .cover {
#             opacity: 0;
#         }
#
#         .show-curtain.opaque #curtain .cover {
#             opacity: 1;
#         }
#
#         #curtain .content {
#             z-index: 2;
#             background: transparent;
#             color: #00E;
#
#             display: flex;
#             flex-direction: column;
#             justify-content: center;
#             align-items: center;
#         }
#
#         .unrecoverable #curtain .content,
#         .unsupported-browser #curtain .content {
#             display: block;
#             align-items: start;
#         }
#
#         #curtain h1 {
#             margin: 0;
#             padding: .5em;
#             background-color: #cccccc;
#         }
#
#         #curtain  p {
#             margin: 1em;
#             color: black;
#         }
#
#         .pacify #curtain .icom-:after {
#             content: "\eb23";
#         }
#
#         #curtain .text {
#             display: none;
#         }
#
#         .loading #curtain .text.loading,
#         .reading #curtain .text.reading,
#         .writing #curtain .text.writing,
#         .saving #curtain .text.saving,
#         .searching #curtain .text.searching,
#         .unrecoverable #curtain .text.unrecoverable,
#         .message #curtain .text.message {
#             display: block;
#         }
#
#         .unrecoverable #curtain .text.unrecoverable {
#         }
#
#         @keyframes rotate {
#             from {
#                 transform: rotate(0deg);
#             }
#             to {
#                 transform: rotate(359deg);
#             }
#         }
#
#         .pacify #curtain .icom- {
#             font-size: 3em;
#             animation: rotate 2s infinite linear;
#         }
#    </style>
#    <script crossorigin="anonymous" src="https://www.craigslist.org/static/www/59219857f2acaf38f9f5507d73c66d097cefa075.js">
#    </script>
#    <script>
#     window.cl.init(
#              'https://www.craigslist.org/static/www/',
#              '',
#              'www',
#              'posting',
#              {
# 'countOfTotalText': "image {count} of {total}",
# 'defaultLocale': "en_US",
# 'imageConfig': {"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"4":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"3":{"sizes":["50x50c","300x300","600x450","1200x900"],"hostname":"https://images.craigslist.org"},"0":{"sizes":["50x50c","300x300","600x450"],"hostname":"https://images.craigslist.org"},"1":{"sizes":["50x50c","300x300","600x450","1200x900"],"hostname":"https://images.craigslist.org"}},
# 'maptileBaseUrl': "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png",
# 'pID': 7838334390
# },
#              0
#          );
#    </script>
#    <script>
#     window.cl.specialCurtainMessages = {
#             unsupportedBrowser: [
#                 "We've detected you are using a browser that is missing critical features.",
#                 "Please visit craigslist from a modern browser."
#             ],
#             unrecoverableError: [
#                 "There was an error loading the page."
#             ]
#         };
#    </script>
#   </link>
#  </head>
#  <body class="no-js show-curtain opaque posting">
#   <iframe id="cl-local-storage" src="https://www.craigslist.org/static/www/localStorage-092e9f9e2f09450529e744902aa7cdb3a5cc868d.html" style="display:none;">
#   </iframe>
#   <section class="page-container">
#    <div class="bglogo">
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="/" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <ul class="breadcrumbs">
#       <li class="crumb area">
#        <p>
#         <a href="/">
#          los angeles
#         </a>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </p>
#       </li>
#       <li class="crumb subarea">
#        <p>
#         <a href="/ant/">
#          antelope valley
#         </a>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </p>
#       </li>
#       <li class="crumb section">
#        <p>
#         <a href="/search/ant/hhh">
#          housing
#         </a>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </p>
#       </li>
#       <li class="crumb category">
#        <p>
#         <a href="/search/ant/apa">
#          apartments / housing for rent
#         </a>
#        </p>
#       </li>
#      </ul>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/lax">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <div class="to-banish-page">
#         <a class="to-banish-page-link" href="#">
#          <span aria-hidden="true" class="icon icon-trash red">
#          </span>
#          <span class="banished_count">
#          </span>
#          <span class="discards-label">
#           hidden
#          </span>
#         </a>
#        </div>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="/">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <div class="breadcrumbs">
#       antelope valley            &gt;
#
# apartments / housing for rent
#      </div>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <section class="body">
#     <header class="dateReplyBar">
#      <div class="prevnext-sec">
#       <div class="prevnext js-only">
#        <a class="prev">
#         ◀  prev
#        </a>
#        <a class="backup" title="back to search">
#         ▲
#        </a>
#        <a class="next">
#         next ▶
#        </a>
#       </div>
#      </div>
#      <div class="reply-button-row">
#       <div class="actions-combo">
#        <button class="reply-button js-only" data-href="/reply/lax/apa/7838334390/__SERVICE_ID__" role="button">
#         reply
#        </button>
#        <div class="reply-info js-only">
#        </div>
#        <div class="fave-unfave action">
#         <div class="fave" role="button" title="add to favorites">
#          <div aria-hidden="true" class="icon icon-star">
#          </div>
#          <div class="action-label">
#           favorite
#          </div>
#         </div>
#         <div class="unfave" role="button" title="remove from favorites">
#          <div aria-hidden="true" class="icon icon-star fav">
#          </div>
#          <div class="action-label">
#           favorite
#          </div>
#         </div>
#        </div>
#        <div class="banish-unbanish action">
#         <div class="banish" data-url="https://post.craigslist.org/flag" role="button" title="hide this posting">
#          <div aria-hidden="true" class="icon icon-trash">
#          </div>
#          <div class="action-label">
#           hide
#          </div>
#         </div>
#         <div class="unbanish" data-url="https://post.craigslist.org/flag" role="button" title="restore this posting">
#          <div aria-hidden="true" class="icon icon-trash red">
#          </div>
#          <div class="action-label">
#           unhide
#          </div>
#         </div>
#        </div>
#        <div class="flag-action action">
#         <div class="flag" data-url="https://post.craigslist.org/flag" role="button" title="flag as prohibited / spam / miscategorized">
#          <div aria-hidden="true" class="flagIcon">
#           <span class="white-flag">
#            ⚐
#           </span>
#           <span class="black-flag">
#            ⚑
#           </span>
#          </div>
#          <div class="action-label">
#           flag
#          </div>
#         </div>
#         <div class="unflag">
#          <div aria-hidden="true" class="flagIcon">
#           ⚑
#          </div>
#          <a class="action-label" href="https://www.craigslist.org/about/help/faqs/flagging" title="thanks for flagging!">
#           flagged
#          </a>
#         </div>
#        </div>
#        <div class="action share-action">
#         <div class="share" id="sharebutton-container">
#         </div>
#        </div>
#       </div>
#       <p class="postinginfo reveal" id="display-date">
#        Posted
#        <time class="date timeago" datetime="2025-03-28T21:16:20-0700">
#         2025-03-28 21:16
#        </time>
#       </p>
#       <p class="print-information print-contact">
#        Contact Information:
#        <span class="print-email">
#        </span>
#        <span class="print-phone">
#        </span>
#       </p>
#       <a href="#" id="printme">
#        print
#       </a>
#      </div>
#     </header>
#     <h1 class="postingtitle">
#      <span class="postingtitletext">
#       <span class="price">
#        $2,780
#       </span>
#       <span class="housing">
#        / 2br - 860ft
#        <sup>
#         2
#        </sup>
#        -
#       </span>
#       <span id="titletextonly">
#        Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!
#       </span>
#       <span>
#        (22640 Garzota Dr, Santa Clarita, CA)
#       </span>
#      </span>
#     </h1>
#     <h2 class="street-address">
#      22640 Garzota Dr, Santa Clarita, CA 91350
#     </h2>
#     <section class="userbody">
#      <figure class="iw multiimage">
#       <div class="gallery">
#        <span class="slider-back arrow">
#         ‹
#        </span>
#        <span class="slider-info">
#         image 1 of 9
#        </span>
#        <span class="slider-forward arrow">
#         ›
#        </span>
#        <div class="swipe">
#         <div class="swipe-wrap">
#          <div class="slide first visible" data-imgid="hp0VIOcQjyz_0pO0hd" id="1_image_hp0VIOcQjyz_0pO0hd">
#           <img alt="Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! 1" onerror="this.onerror = null; this.style.width='650px'; this.style.height='400px'; this.src='/images/no_image.png'" src="https://images.craigslist.org/00d0d_hp0VIOcQjyz_0pO0hd_600x450.jpg" title="1"/>
#          </div>
#          <div class="slide" data-imgid="kyAac5SLXt2_0pO0hd" id="2_image_kyAac5SLXt2_0pO0hd">
#          </div>
#          <div class="slide" data-imgid="bPAdKVqaWaX_0pO0hd" id="3_image_bPAdKVqaWaX_0pO0hd">
#          </div>
#          <div class="slide" data-imgid="jbWC40uXduh_0pO0hd" id="4_image_jbWC40uXduh_0pO0hd">
#          </div>
#          <div class="slide" data-imgid="8nVqNstx6T1_0pO0hd" id="5_image_8nVqNstx6T1_0pO0hd">
#          </div>
#          <div class="slide" data-imgid="64hUv031SiU_0pO0hd" id="6_image_64hUv031SiU_0pO0hd">
#          </div>
#          <div class="slide" data-imgid="8odp5Qq5LrB_0pO0hd" id="7_image_8odp5Qq5LrB_0pO0hd">
#          </div>
#          <div class="slide" data-imgid="irw9raYAy3s_0pO0hd" id="8_image_irw9raYAy3s_0pO0hd">
#          </div>
#          <div class="slide" data-imgid="8TQ19SkZYxR_04P02I" id="9_image_8TQ19SkZYxR_04P02I">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div id="thumbs">
#        <a class="thumb" data-imgid="hp0VIOcQjyz_0pO0hd" href="https://images.craigslist.org/00d0d_hp0VIOcQjyz_0pO0hd_600x450.jpg" id="1_thumb_hp0VIOcQjyz_0pO0hd" title="1">
#         <img alt="Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! 1 thumbnail" class="selected" onerror="this.onerror = null; this.src='/images/no_image.png'" src="https://images.craigslist.org/00d0d_hp0VIOcQjyz_0pO0hd_50x50c.jpg"/>
#        </a>
#        <a class="thumb" data-imgid="kyAac5SLXt2_0pO0hd" href="https://images.craigslist.org/00k0k_kyAac5SLXt2_0pO0hd_600x450.jpg" id="2_thumb_kyAac5SLXt2_0pO0hd" title="2">
#         <img alt="Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! 2 thumbnail" onerror="this.onerror = null; this.src='/images/no_image.png'" src="https://images.craigslist.org/00k0k_kyAac5SLXt2_0pO0hd_50x50c.jpg"/>
#        </a>
#        <a class="thumb" data-imgid="bPAdKVqaWaX_0pO0hd" href="https://images.craigslist.org/00f0f_bPAdKVqaWaX_0pO0hd_600x450.jpg" id="3_thumb_bPAdKVqaWaX_0pO0hd" title="3">
#         <img alt="Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! 3 thumbnail" onerror="this.onerror = null; this.src='/images/no_image.png'" src="https://images.craigslist.org/00f0f_bPAdKVqaWaX_0pO0hd_50x50c.jpg"/>
#        </a>
#        <a class="thumb" data-imgid="jbWC40uXduh_0pO0hd" href="https://images.craigslist.org/00f0f_jbWC40uXduh_0pO0hd_600x450.jpg" id="4_thumb_jbWC40uXduh_0pO0hd" title="4">
#         <img alt="Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! 4 thumbnail" onerror="this.onerror = null; this.src='/images/no_image.png'" src="https://images.craigslist.org/00f0f_jbWC40uXduh_0pO0hd_50x50c.jpg"/>
#        </a>
#        <a class="thumb" data-imgid="8nVqNstx6T1_0pO0hd" href="https://images.craigslist.org/00z0z_8nVqNstx6T1_0pO0hd_600x450.jpg" id="5_thumb_8nVqNstx6T1_0pO0hd" title="5">
#         <img alt="Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! 5 thumbnail" onerror="this.onerror = null; this.src='/images/no_image.png'" src="https://images.craigslist.org/00z0z_8nVqNstx6T1_0pO0hd_50x50c.jpg"/>
#        </a>
#        <a class="thumb" data-imgid="64hUv031SiU_0pO0hd" href="https://images.craigslist.org/00707_64hUv031SiU_0pO0hd_600x450.jpg" id="6_thumb_64hUv031SiU_0pO0hd" title="6">
#         <img alt="Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! 6 thumbnail" onerror="this.onerror = null; this.src='/images/no_image.png'" src="https://images.craigslist.org/00707_64hUv031SiU_0pO0hd_50x50c.jpg"/>
#        </a>
#        <a class="thumb" data-imgid="8odp5Qq5LrB_0pO0hd" href="https://images.craigslist.org/00K0K_8odp5Qq5LrB_0pO0hd_600x450.jpg" id="7_thumb_8odp5Qq5LrB_0pO0hd" title="7">
#         <img alt="Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! 7 thumbnail" onerror="this.onerror = null; this.src='/images/no_image.png'" src="https://images.craigslist.org/00K0K_8odp5Qq5LrB_0pO0hd_50x50c.jpg"/>
#        </a>
#        <a class="thumb" data-imgid="irw9raYAy3s_0pO0hd" href="https://images.craigslist.org/00F0F_irw9raYAy3s_0pO0hd_600x450.jpg" id="8_thumb_irw9raYAy3s_0pO0hd" title="8">
#         <img alt="Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! 8 thumbnail" onerror="this.onerror = null; this.src='/images/no_image.png'" src="https://images.craigslist.org/00F0F_irw9raYAy3s_0pO0hd_50x50c.jpg"/>
#        </a>
#        <a class="thumb" data-imgid="8TQ19SkZYxR_04P02I" href="https://images.craigslist.org/00R0R_8TQ19SkZYxR_04P02I_600x450.jpg" id="9_thumb_8TQ19SkZYxR_04P02I" title="9">
#         <img alt="Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! 9 thumbnail" onerror="this.onerror = null; this.src='/images/no_image.png'" src="https://images.craigslist.org/00R0R_8TQ19SkZYxR_04P02I_50x50c.jpg"/>
#        </a>
#       </div>
#       <script>
#        var imgList = [{"shortid":"hp0VIOcQjyz_0pO0hd","url":"https://images.craigslist.org/00d0d_hp0VIOcQjyz_0pO0hd_600x450.jpg","altBase":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!","thumb":"https://images.craigslist.org/00d0d_hp0VIOcQjyz_0pO0hd_50x50c.jpg","imgid":"3:00d0d_hp0VIOcQjyz_0pO0hd"},{"altBase":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!","thumb":"https://images.craigslist.org/00k0k_kyAac5SLXt2_0pO0hd_50x50c.jpg","shortid":"kyAac5SLXt2_0pO0hd","url":"https://images.craigslist.org/00k0k_kyAac5SLXt2_0pO0hd_600x450.jpg","imgid":"3:00k0k_kyAac5SLXt2_0pO0hd"},{"imgid":"3:00f0f_bPAdKVqaWaX_0pO0hd","shortid":"bPAdKVqaWaX_0pO0hd","url":"https://images.craigslist.org/00f0f_bPAdKVqaWaX_0pO0hd_600x450.jpg","altBase":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!","thumb":"https://images.craigslist.org/00f0f_bPAdKVqaWaX_0pO0hd_50x50c.jpg"},{"url":"https://images.craigslist.org/00f0f_jbWC40uXduh_0pO0hd_600x450.jpg","shortid":"jbWC40uXduh_0pO0hd","thumb":"https://images.craigslist.org/00f0f_jbWC40uXduh_0pO0hd_50x50c.jpg","altBase":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!","imgid":"3:00f0f_jbWC40uXduh_0pO0hd"},{"thumb":"https://images.craigslist.org/00z0z_8nVqNstx6T1_0pO0hd_50x50c.jpg","altBase":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!","url":"https://images.craigslist.org/00z0z_8nVqNstx6T1_0pO0hd_600x450.jpg","shortid":"8nVqNstx6T1_0pO0hd","imgid":"3:00z0z_8nVqNstx6T1_0pO0hd"},{"imgid":"3:00707_64hUv031SiU_0pO0hd","url":"https://images.craigslist.org/00707_64hUv031SiU_0pO0hd_600x450.jpg","shortid":"64hUv031SiU_0pO0hd","thumb":"https://images.craigslist.org/00707_64hUv031SiU_0pO0hd_50x50c.jpg","altBase":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!"},{"imgid":"3:00K0K_8odp5Qq5LrB_0pO0hd","thumb":"https://images.craigslist.org/00K0K_8odp5Qq5LrB_0pO0hd_50x50c.jpg","altBase":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!","url":"https://images.craigslist.org/00K0K_8odp5Qq5LrB_0pO0hd_600x450.jpg","shortid":"8odp5Qq5LrB_0pO0hd"},{"thumb":"https://images.craigslist.org/00F0F_irw9raYAy3s_0pO0hd_50x50c.jpg","altBase":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!","url":"https://images.craigslist.org/00F0F_irw9raYAy3s_0pO0hd_600x450.jpg","shortid":"irw9raYAy3s_0pO0hd","imgid":"3:00F0F_irw9raYAy3s_0pO0hd"},{"thumb":"https://images.craigslist.org/00R0R_8TQ19SkZYxR_04P02I_50x50c.jpg","altBase":"Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now!","url":"https://images.craigslist.org/00R0R_8TQ19SkZYxR_04P02I_600x450.jpg","shortid":"8TQ19SkZYxR_04P02I","imgid":"3:00R0R_8TQ19SkZYxR_04P02I"}];
#       </script>
#      </figure>
#      <div class="mapAndAttrs">
#       <div class="mapbox">
#        <div class="viewposting" data-accuracy="5" data-latitude="34.437459" data-longitude="-118.531770" id="map">
#        </div>
#        <div class="mapaddress">
#         22640 Garzota Dr
#        </div>
#        <p class="mapaddress">
#         <small>
#          <a href="https://www.google.com/maps/search/34.437459,-118.531770" target="_blank">
#           google map
#           <span class="icom-">
#            
#           </span>
#          </a>
#         </small>
#        </p>
#       </div>
#       <div class="attrgroup">
#        <span class="attr important">
#         2BR / 1Ba
#        </span>
#        <span class="attr important">
#         860ft
#         <sup>
#          2
#         </sup>
#        </span>
#       </div>
#       <div class="attrgroup">
#        <div class="attr rent_period">
#         <span class="labl">
#          rent period:
#         </span>
#         <span class="valu">
#          <a href="//losangeles.craigslist.org/search/apa?rent_period=3">
#           monthly
#          </a>
#         </span>
#        </div>
#       </div>
#       <div class="attrgroup">
#        <div class="attr pets_cat">
#         <span class="valu">
#          <a href="//losangeles.craigslist.org/search/apa?pets_cat=1">
#           cats are OK - purrr
#          </a>
#         </span>
#        </div>
#        <div class="attr">
#         <span class="valu">
#          <a href="//losangeles.craigslist.org/search/apa?housing_type=1">
#           apartment
#          </a>
#         </span>
#        </div>
#        <div class="attr pets_dog">
#         <span class="valu">
#          <a href="//losangeles.craigslist.org/search/apa?pets_dog=1">
#           dogs are OK - wooof
#          </a>
#         </span>
#        </div>
#        <div class="attr">
#         <span class="valu">
#          <a href="//losangeles.craigslist.org/search/apa?laundry=3">
#           laundry on site
#          </a>
#         </span>
#        </div>
#        <div class="attr">
#         <span class="valu">
#          <a href="//losangeles.craigslist.org/search/apa?parking=1">
#           carport
#          </a>
#         </span>
#        </div>
#        <div class="attr no_smoking">
#         <span class="valu">
#          <a href="//losangeles.craigslist.org/search/apa?no_smoking=1">
#           no smoking
#          </a>
#         </span>
#        </div>
#        <div class="attr airconditioning">
#         <span class="valu">
#          <a href="//losangeles.craigslist.org/search/apa?airconditioning=1">
#           air conditioning
#          </a>
#         </span>
#        </div>
#       </div>
#      </div>
#      <section id="postingbody">
#       <div class="print-information print-qrcode-container">
#        <p class="print-qrcode-label">
#         QR Code Link to This Post
#        </p>
#        <div class="print-qrcode" data-location="https://losangeles.craigslist.org/ant/apa/d/valencia-charming-br-ba-with-1000-off/7838334390.html">
#        </div>
#       </div>
#       <h3>
#        22640 Garzota Dr, Santa Clarita, CA 91350
#       </h3>
#       <hr/>
#       Welcome to Arrive Santa Clarita, a captivating community offering luxurious one- and two-bedroom apartment homes. Relish the serenity of the nearby landscapes with their enchanting walking paths or enjoy the opulent comforts of our community. Those with active lifestyles will benefit from our modern fitness center, and pet lovers will be charmed by our special areas dedicated to furry friends. Discover your new home at Arrive Santa Clarita.
#       <h3>
#        Apartment Features:
#       </h3>
#       <ul>
#        <li>
#         White or Stainless-Steel Appliances
#        </li>
#        <li>
#         Range
#        </li>
#        <li>
#         White Countertops
#        </li>
#        <li>
#         Spacious closets
#        </li>
#        <li>
#         Carport
#        </li>
#        <li>
#         Air Conditioner
#        </li>
#        <li>
#         Microwave
#        </li>
#        <li>
#         Private Balcony
#        </li>
#       </ul>
#       <h3>
#        Community Features:
#       </h3>
#       <ul>
#        <li>
#         Short Term Lease
#        </li>
#        <li>
#         Water Sewer And Trash
#        </li>
#        <li>
#         Pool
#        </li>
#        <li>
#         Covered Parking
#        </li>
#        <li>
#         On-site Management
#        </li>
#        <li>
#         Internet Access: High-Speed
#        </li>
#        <li>
#         24-Hour Availability
#        </li>
#        <li>
#         Fitness Center
#        </li>
#       </ul>
#       <br/>
#       <br/>
#       <b>
#        Call:
#        <a class="show-contact" data-href="/reply/lax/apa/7838334390/__SERVICE_ID__" href="#" rel="nofollow" title="click to show contact info">
#         show contact info
#        </a>
#       </b>
#       <br/>
#       <br/>
#       For more information, visit us at: https://trinity-apt.com/kjrqzzto/arrive-santa-clarita
#       <br/>
#       <br/>
#       <b>
#        Pricing and availability are subject to change.
#       </b>
#      </section>
#      <ul class="notices">
#      </ul>
#      <div class="postinginfos">
#       <p class="postinginfo">
#        post id: 7838334390
#       </p>
#       <p class="postinginfo reveal">
#        posted:
#        <time class="date timeago" datetime="2025-03-28T21:16:20-0700">
#         2025-03-28 21:16
#        </time>
#       </p>
#       <p class="postinginfo reveal">
#        updated:
#        <time class="date timeago" datetime="2025-04-15T16:23:32-0700">
#         2025-04-15 16:23
#        </time>
#       </p>
#       <p class="postinginfo">
#        <a class="bestof-link" href="https://post.craigslist.org/flag" title="nominate for best-of-CL">
#         <span class="bestof-icon">
#          ♥
#         </span>
#         <span class="bestof-text">
#          best of
#         </span>
#        </a>
#        <sup>
#         [
#         <a href="https://www.craigslist.org/about/best-of-craigslist">
#          ?
#         </a>
#         ]
#        </sup>
#       </p>
#      </div>
#      <div class="print-information print-pics">
#      </div>
#     </section>
#     <div class="psa-box">
#     </div>
#     <div class="avoid-scams">
#      <aside class="tsb">
#       <a href="https://www.craigslist.org/about/scams">
#        Avoid scams, deal locally!
#       </a>
#       <em>
#        DO NOT wire funds (e.g. Western Union)
#       </em>
#       , or buy/rent sight unseen
#      </aside>
#     </div>
#    </section>
#    <footer>
#     <ul class="clfooter">
#      <li>
#       © 2025
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/safety">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/terms.of.use">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/craigslist_app">
#        app
#       </a>
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <div id="curtain">
#    <div class="cover">
#    </div>
#    <div class="content">
#     <div class="icom-">
#     </div>
#     <div class="text loading">
#      loading
#     </div>
#     <div class="text reading">
#      reading
#     </div>
#     <div class="text writing">
#      writing
#     </div>
#     <div class="text saving">
#      saving
#     </div>
#     <div class="text searching">
#      searching
#     </div>
#     <div class="text message" id="curtainText">
#     </div>
#     <div class="text unrecoverable">
#      <p>
#       <a href="#" id="cl-unrecoverable-hard-refresh" onclick="location.reload(true);">
#        refresh the page.
#       </a>
#      </p>
#     </div>
#    </div>
#   </div>
#   <noscript id="no-js">
#    <div>
#     <h1>
#      Charming 2 BR 1 BA with $1,000 Off Move-in Special! Lease Now! -...
#     </h1>
#     <p>
#      22640 Garzota Dr, Santa Clarita, CA 91350 Welcome to Arrive Santa Clarita, a captivating community offering luxurious one- and two-bedroom apartment homes. Relish the serenity of the nearby...
#     </p>
#     <aside class="error-message">
#      <p>
#       We've detected that JavaScript is not enabled in your browser. You must enable JavaScript to use craigslist.
#      </p>
#     </aside>
#    </div>
#   </noscript>
#  </body>
# </html>

# %%
# in my example, the webpage said "carport" in the right hand panel
# I did a search with "Control+F" in the developer's window, and this was the result

#<div class="attrgroup">
#       <div class="attr rent_period">
#        <span class="labl">
# ...
#       <div class="attr">
#        <span class="valu">
#         <a href="//losangeles.craigslist.org/search/apa?parking=1">
#          carport
#         </a>
#        </span>
#       </div>


# so it looks like we want the class "value"
links = soup.find_all(class_='valu')

#ここで、"valu"はspan classの中にあるが、spanは指定しなくていい？
#→class_='valu'だと、class="valu"を持つ要素をすべて探す という処理。つまり div, span, li, どんなタグでもOK
#soup.find_all('span', class_='valu')とすると、class='valu' を持つ <span>タグだけに絞って検索

#links = soup.find_all(class_='valu')はclass名だけ指定（どんなタグでも探す）
#links = soup.find_all('span', class_='valu')はspanタグかつ class='valu' のみに限定

# %%
# I see that the result was a list, with the carport in "a href" which includes "parking"
links
# Out:
# [<span class="valu"> <a href="//losangeles.craigslist.org/search/apa?rent_period=3">monthly</a>
#  </span>,
#  <span class="valu"> <a href="//losangeles.craigslist.org/search/apa?pets_cat=1">cats are OK - purrr</a>
#  </span>,
#  <span class="valu"> <a href="//losangeles.craigslist.org/search/apa?housing_type=1">apartment</a>
#  </span>,
#  <span class="valu"> <a href="//losangeles.craigslist.org/search/apa?pets_dog=1">dogs are OK - wooof</a>
#  </span>,
#  <span class="valu"> <a href="//losangeles.craigslist.org/search/apa?laundry=3">laundry on site</a>
#  </span>,
#  <span class="valu"> <a href="//losangeles.craigslist.org/search/apa?parking=1">carport</a>
#  </span>,
#  <span class="valu"> <a href="//losangeles.craigslist.org/search/apa?no_smoking=1">no smoking</a>
#  </span>,
#  <span class="valu"> <a href="//losangeles.craigslist.org/search/apa?airconditioning=1">air conditioning</a>
#  </span>]

# %%
# so I can loop over those links, and find the one that includes "parking" in "href"
for link in links:
    if 'parking' in link.find('a')['href']:
        print(link.text)
    else:
        continue

# A simpler way would be to search for "no parking" in r.text! 

#HTMLの中では"a href"となっているのに、なぜ検索する時にはaとhrefを分ける？
#→<a> タグと href 属性は HTML の中で 役割が違う。<a> は「リンク要素全体（タグ）」、href はその中の「リンク先のURL（属性）」
#例えば<a href="https://example.com">Click here</a>でtag = soup.find('a')とすると

#<a>はアンカータグ（リンクを示す要素）soup.find('a')で呼び出し
    #print(tag)           # <a href="https://example.com">Click here</a>
#href="..."はaタグの属性（リンク先URL）tag['href']で呼び出し
    #print(tag['href'])   # https://example.com
#Click hereはaタグの中のテキスト（リンク名）tag.textで呼び出し
    #print(tag.text)      # Click here
# Out:
#  carport

# %%
# what about lat and lon?
# I found this in <div id="map" class="viewposting"
links = soup.find_all('div', class_='viewposting')
links

#div id="map"の中にあるのに、なぜfind_allの後は'div id'ではなく'div'でよい？
#'div' は タグ名（=要素の種類） を指定していて、'id="map"' はその 属性 を別で指定しているから
#div はタグの種類（HTML要素のタイプ）
#id="map" はタグの属性（他にも class=, href=, src= などがある）
#BeautifulSoupでは「soup.find(タグ名, 属性名=値, 属性名2=値2, ...)」という形式で書く

#ちなみに、属性にはidやhref、classなどがあるが、classだけはPythonの予約語なので、class_とする
# Out:
# [<div class="viewposting" data-accuracy="5" data-latitude="34.437459" data-longitude="-118.531770" id="map"></div>]

# %%
# it's in a list of length 1
# we could get this via link = links[0]
# or use find (which gets the first instance) rather than find_all
link = soup.find('div', class_='viewposting')
link
# Out:
# <div class="viewposting" data-accuracy="5" data-latitude="34.437459" data-longitude="-118.531770" id="map"></div>

# %%
link.attrs
# Out:
# {'id': 'map',
#  'class': ['viewposting'],
#  'data-latitude': '34.437459',
#  'data-longitude': '-118.531770',
#  'data-accuracy': '5'}

# %%
# This functions like a dictionary object!
lat = link['data-latitude']
lon = link['data-longitude']
lat, lon

#なぜlat = link['data-latitude']という構文でdata-latitudeの内容が引き出せる？
#→HTMLの属性 = Pythonでは辞書のように扱われるから
#BeautifulSoupで取得したタグ（たとえば <div>）は、Pythonの辞書のような構造をしている
#上のlinkの中身の場合だと、link.attrsの結果にあるように辞書構造として扱われている
#なのでlink['data-latitude']という指示で内容が引き出せる
# Out:
# ('34.437459', '-118.531770')

# %% [markdown]
# Now you've written this code, a next step would be to package it in a function that you can apply to all the URLs in your dataframe of posts (like the one we created in the video lecture).

# %% [markdown]
# ## Large language models [Optional]

# %% [markdown]
# Large language models (LLMs) such as ChatGPT can also be accessed via an API.
#
# The APIs are changing very rapidly, as are the pricing structures. For now, some LLMs are offered for free, for limited use. One such model with a free tier is Gemini, by Google.
#
# If you'd like to experiment with Gemini, you need to [get an API key here](https://aistudio.google.com/u/1/apikey). No credit card is necessary, but your UCLA Google account won't work - you need a personal Google account.
#
# [The documentation and some examples are here](https://github.com/googleapis/python-genai).
#
# The other challenge with Gemini is that its Python library has several incompatibilities, including with some of the ones we use elsewhere in the course. So you will need to create a new environment in Anaconda, using the same setup process (importing an environment) as you did at the [start of the course](https://urbandatascience.its.ucla.edu/getting-started/).
#
# Specifically:
# - In Anaconda, go to the Environments tab
# - Click on Import
# - Choose `google-genai-env.yml` under Local Drive, and call the environment `genai`
# - Manually add the `google-genai` package (choose "Not Installed", type `google-genai` into the search bar, select the checkbox, and then click Apply at the bottom of the screen)
# - Anaconda will take some time, before you can click Apply again to install
# - Close this notebook and open it again after you switch to your new `genai` environment
#
# All set up? Let's look at a simple example---passing a query to the chat interface.

# %%
from google import genai  # if this doesn't load, you probably have the wrong environment
gemini_api_key = 'XXXXX' #'XXXXX' # fill in your key here

c = genai.Client(api_key=gemini_api_key)
chat = c.chats.create(model='gemini-2.0-flash-001')
response = chat.send_message('What do urban planners need to learn about gen AI?')
print(response.text)

# %% [markdown]
# How might this be used in web scraping?
#
# Well, perhaps you can ask it to parse the text.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <strong>Exercise:</strong> Pass the text of the craiglist post to Gemini, and ask it to return the number of parking spaces (if any). Add the result to your dataframe. NOTE: This exercise is optional (you might not want to create a Google account to get an API key).

# %%
# your code here
c = genai.Client(api_key=gemini_api_key)
chat = c.chats.create(model='gemini-2.0-flash-001')
url = 'https://losangeles.craigslist.org/ant/apa/d/valencia-charming-br-ba-with-1000-off/7838334390.html'

response = chat.send_message('Does this Craiglist posting have parking? If so, which type? URL:'+url)
print(response.text)

# %% [markdown]
# We won't do it here, but [you can also experiment with the MetaAI API](https://github.com/Strvm/meta-ai-api). The advantage: it doesn't need an API key, but the capabilities are a bit more limited. You can also find the Meta installed in the `genai` environment.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h3>What you should have learned</h3>
# <ul>
#   <li>Gain confidence in experimenting with code - exploring different objects, writing functions, and so on</li>
#   <li>Learn how to extract information from a scraped webpage - how to do the detective work.</li>
#   <li>Gain confidence in debugging errors.</li>
#   <li>Learn how to integrate Large Language Models into Python</li>
# </ul>
# </div>
